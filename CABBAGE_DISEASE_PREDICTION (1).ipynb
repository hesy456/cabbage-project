# %% [markdown]
# **Importing Necessary Libraries**

# %% [markdown]
# This code imports essential libraries for handling files, processing images, visualizing data, and building a deep learning model.

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from PIL import Image
import numpy as np
from hashlib import md5
import tensorflow as tf
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential

# %% [markdown]
# **Verifying Dataset Directory and Listing Classes**

# %% [markdown]
# This code checks if the specified dataset directory exists. If it does, it lists and prints the classes (subdirectories) inside it; otherwise, it notifies the user that the path is missing or the dataset extraction was unsuccessful.

# %%
dataset_path = "F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES"

# %%
# Define classes based on folder names
classes = os.listdir(dataset_path)
print("Classes:",classes)
# Out:
# Classes: ['Cabbage - Black_rot', 'Cabbage - Healthy', 'Cabbage downy mildew - Original', 'Cabbage_Altenaria_spot']

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# **Check Class Distribution**

# %% [markdown]
# This code checks if the dataset directory exists. If it does, it counts and prints the number of classes (disease categories) and their names. It then calculates the number of images in each class and visualizes the class distribution using a bar plot. If the dataset path is missing, it alerts the user.

# %%
dataset_path = dataset_path = "F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES"

if os.path.exists(dataset_path):
    classes = os.listdir(dataset_path)
    print("Number of classes:", len(classes))
    print("Classes:", classes)

    class_counts = {cls: len(os.listdir(os.path.join(dataset_path, cls))) for cls in classes}

    # Plot class distribution
    plt.figure(figsize=(10, 5))
    sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()))
    plt.xticks(rotation=45)
    plt.xlabel("Disease Classes")
    plt.ylabel("Number of Images")
    plt.title("Class Distribution of Cabbage Diseases Dataset")
    plt.show()
else:
    print("Dataset path does not exist.")
# Out:
# Number of classes: 4
# Classes: ['Cabbage - Black_rot', 'Cabbage - Healthy', 'Cabbage downy mildew - Original', 'Cabbage_Altenaria_spot']

# %% [markdown]
# **Display Sample Images**

# %% [markdown]
# This function, show_sample_images(), displays a few sample images from each class in the dataset. It loops through the disease categories, selects a specified number of images (default is 3), and plots them in a grid. Each image is displayed without axes, and the class name is used as the title. The function is then called to visualize the dataset's sample images.

# %%
def show_sample_images(dataset_path, classes, num_samples=3):
    plt.figure(figsize=(12, len(classes) * 3))

    for i, cls in enumerate(classes):
        class_path = os.path.join(dataset_path, cls)
        images = os.listdir(class_path)[:num_samples]

        for j, img_name in enumerate(images):
            img_path = os.path.join(class_path, img_name)
            img = Image.open(img_path)

            plt.subplot(len(classes), num_samples, i * num_samples + j + 1)
            plt.imshow(img)
            plt.axis("off")
            plt.title(cls)

    plt.tight_layout()
    plt.show()


show_sample_images(dataset_path, classes)

# %% [markdown]
# **Image Size Distribution**

# %% [markdown]
# This code analyzes the distribution of image sizes in the dataset. It collects the width and height of up to 50 images per class, stores them in a list, and then converts them into a NumPy array. Using Seaborn, it plots histograms with kernel density estimation (KDE) to visualize the frequency distribution of image widths and heights. Blue represents width, and red represents height.

# %%
image_sizes = []
for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    image_files = os.listdir(class_path)[:50]

    for img_name in image_files:
        img_path = os.path.join(class_path, img_name)
        img = Image.open(img_path)
        image_sizes.append(img.size)

# Convert sizes to NumPy array and plot
widths, heights = zip(*image_sizes)

plt.figure(figsize=(10, 5))
sns.histplot(widths, bins=20, color="blue", label="Width", kde=True)
sns.histplot(heights, bins=20, color="red", label="Height", kde=True)
plt.legend()
plt.xlabel("Pixels")
plt.ylabel("Frequency")
plt.title("Distribution of Image Sizes")
plt.show()

# %% [markdown]
# **Check for Duplicate Images**

# %% [markdown]
# This code detects duplicate images in the dataset by computing a unique hash for each image file using the MD5 algorithm. It iterates through all images in each class, storing their hashes in a set. If an image's hash matches one already in the set, it is flagged as a duplicate and added to a list. Finally, the total number of duplicate images found is printed.

# %%
def get_file_hash(file_path):
    with open(file_path, "rb") as f:
        return md5(f.read()).hexdigest()

hashes = set()
duplicates = []

for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)
        file_hash = get_file_hash(img_path)

        if file_hash in hashes:
            duplicates.append(img_path)
        else:
            hashes.add(file_hash)

print(f"Found {len(duplicates)} duplicate images.")
# Out:
# Found 14 duplicate images.

# %% [markdown]
# **Removing Duplicate Images from the Dataset**

# %% [markdown]
# This code removes duplicate images from the dataset. It iterates through the list of duplicate image paths and deletes each file using os.remove(), printing a confirmation message for each deleted image. Once all duplicates are removed, it prints a final success message.

# %%
# Remove duplicate images
for img_path in duplicates:
    os.remove(img_path)
    print(f"Deleted: {img_path}")

print("Duplicate images removed successfully.")
# Out:
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(28).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(29).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(31).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(32).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(33).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(34).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(35).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Black_rot\Cabbage__Black_rot(36).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Healthy\Cabbage__Healthy(39).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Healthy\Cabbage__Healthy(65).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Healthy\Cabbage__Healthy(66).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Healthy\Cabbage__Healthy(67).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage - Healthy\Cabbage__Healthy(68).jpg
# Deleted: F:/OneDrive/Desktop/MY WORK/Cabbage project/ORIGINAL_ALL_COMBINE_CABBAGE_DISEASES\Cabbage_Altenaria_spot\Cabbage__Alternaria_spot(68).jpg
# Duplicate images removed successfully.

# %% [markdown]
# **Class-wise Image Count After Removing Duplicates**

# %% [markdown]
# This code counts the number of images in each class after removing duplicates. It first retrieves the list of classes, ensuring they are directories, and then counts the images in each class. The updated class distribution is visualized using a bar chart, with different colors representing different classes. The x-axis labels are rotated for better readability.

# %%
# Count images per class
class_counts = {}
classes = os.listdir(dataset_path)

for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    if os.path.isdir(class_path):
        class_counts[cls] = len(os.listdir(class_path))

# Plot the updated class distribution
plt.figure(figsize=(8, 5))
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'green', 'red', 'purple'])
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.title("Updated Class Distribution After Removing Duplicates")
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# **Updated Image Count Per Class After Removing Duplicates**

# %% [markdown]
# This code counts the number of images in each class after removing duplicates and prints the updated counts. It ensures that only directories are considered as classes and then iterates through them to count the number of images in each. Finally, it prints the class names along with the corresponding image counts.

# %%
# Count images per class
class_counts = {}
classes = os.listdir(dataset_path)

for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    if os.path.isdir(class_path):
        class_counts[cls] = len(os.listdir(class_path))

# Print class counts
print("Updated Class Counts After Removing Duplicates:")
for cls, count in class_counts.items():
    print(f"{cls}: {count} images")
# Out:
# Updated Class Counts After Removing Duplicates:
# Cabbage - Black_rot: 29 images
# Cabbage - Healthy: 63 images
# Cabbage downy mildew - Original: 30 images
# Cabbage_Altenaria_spot: 69 images

# %% [markdown]
# **Convert Images to Numpy and Check Mean Pixel Value**

# %% [markdown]
# This code calculates and visualizes the distribution of mean pixel values for a subset of images in the dataset. It processes up to 10 images per class, converts them to RGB format, normalizes pixel values to the range [0,1], and computes the mean pixel value for each image. These values are then plotted using a histogram with kernel density estimation (KDE) to show the frequency distribution of mean pixel intensities

# %%
mean_pixel_values = []

for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    images = os.listdir(class_path)[:10]  # Limit to 10 images per class

    for img_name in images:
        img_path = os.path.join(class_path, img_name)
        img = Image.open(img_path).convert("RGB")
        img_array = np.array(img) / 255.0  # Normalize

        mean_pixel_values.append(img_array.mean())

plt.figure(figsize=(8, 5))
sns.histplot(mean_pixel_values, bins=20, kde=True)
plt.xlabel("Mean Pixel Value")
plt.ylabel("Frequency")
plt.title("Distribution of Mean Pixel Values")
plt.show()

# %% [markdown]
# **Check for Corrupt Images**

# %% [markdown]
# This function checks for corrupt images in the dataset by attempting to open and verify each image file. If an image cannot be opened, it is flagged as corrupt and added to a list. The function then prints the total number of corrupt images found and returns the list of corrupt image paths.

# %%
def check_corrupt_images(dataset_path, classes):
    corrupt_images = []

    for cls in classes:
        class_path = os.path.join(dataset_path, cls)
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                img = Image.open(img_path)
                img.verify()  # Verify if image is valid
            except Exception as e:
                corrupt_images.append(img_path)

    print(f"Found {len(corrupt_images)} corrupt images.")
    return corrupt_images

corrupt_images = check_corrupt_images(dataset_path, classes)
# Out:
# Found 0 corrupt images.

# %% [markdown]
# **Resizing Images**

# %% [markdown]
# This code sets the image size to 224x224 pixels for consistency and defines a batch size of 32 for efficient processing during model training.

# %%
img_size = (224, 224)
batch_size = 32

# %% [markdown]
# **Data Augmentation and Normalization**

# %% [markdown]
# This code initializes an ImageDataGenerator for data augmentation, applying transformations like rescaling, rotation, shifting, shearing, zooming, and flipping to enhance model generalization while reserving 20% of the data for validation.

# %%
datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split = 0.2,
    channel_shift_range=0
)

# %% [markdown]
# **Training Data Generator with Augmentation for Multi-Class Classification**

# %% [markdown]
# This code creates a training data generator that loads images from the dataset directory, resizes them to 224x224 pixels, applies data augmentation, and organizes them into batches of 32, using categorical labels for multi-class classification.

# %%
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 154 images belonging to 4 classes.

# %% [markdown]
# **Validation Data Generator with Rescaling for Multi-Class Classification**

# %% [markdown]
# This code creates a validation data generator that loads images from the dataset directory, resizes them to 224x224 pixels, applies rescaling, and organizes them into batches of 32, using categorical labels for multi-class classification.

# %%
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 35 images belonging to 4 classes.

# %% [markdown]
# **Visualizing a Batch of Training Images in a 3x3 Grid**

# %% [markdown]
# This code retrieves a batch of images and their labels from the training generator, then displays the first 9 images in a 3x3 grid using Matplotlib.

# %%
images, labels = next(train_generator)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    plt.axis('off')
plt.show()

# %% [markdown]
# **Defining a CNN Model for Multi-Class Image Classification**

# %% [markdown]
# This function defines a Convolutional Neural Network (CNN) model with three convolutional layers for feature extraction, max pooling layers for dimensionality reduction, a fully connected layer for classification, and a dropout layer to prevent overfitting. The final layer uses a softmax activation function to classify images into multiple categories.

# %%
# Define the CNN model
def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %% [markdown]
# **Configuring the CNN Model for Training**

# %% [markdown]
# This code sets up the CNN model for training by defining the image input size and the number of output classes. It then initializes the model using the previously defined create_cnn_model function and compiles it with the Adam optimizer, categorical cross-entropy loss (suitable for multi-class classification), and accuracy as the evaluation metric.

# %%
# Model parameters
img_size = (224, 224, 3)  # Image dimensions
num_classes = len(classes)  # Number of disease categories

# Create model
model = create_cnn_model(img_size, num_classes)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# **Training the CNN Model with Validation**

# %% [markdown]
# This code trains the CNN model using the training dataset (train_generator) and evaluates it on the validation dataset (validation_generator) for 20 epochs, displaying training progress (verbose=1).

# %%
# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=300,
    verbose=1
)
# Out:
# Epoch 1/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 49s 9s/step - accuracy: 0.9197 - loss: 0.2227 - val_accuracy: 0.6000 - val_loss: 2.1029
# Epoch 2/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9198 - loss: 0.1867 - val_accuracy: 0.6000 - val_loss: 2.8765
# Epoch 3/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8838 - loss: 0.2728 - val_accuracy: 0.5429 - val_loss: 3.3443
# Epoch 4/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9427 - loss: 0.1892 - val_accuracy: 0.5714 - val_loss: 1.9015
# Epoch 5/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9536 - loss: 0.1540 - val_accuracy: 0.6000 - val_loss: 3.2453
# Epoch 6/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8766 - loss: 0.3174 - val_accuracy: 0.6857 - val_loss: 3.6255
# Epoch 7/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9017 - loss: 0.2031 - val_accuracy: 0.6000 - val_loss: 3.0500
# Epoch 8/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9260 - loss: 0.1934 - val_accuracy: 0.6286 - val_loss: 3.2856
# Epoch 9/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8946 - loss: 0.2446 - val_accuracy: 0.6286 - val_loss: 2.7851
# Epoch 10/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9136 - loss: 0.2065 - val_accuracy: 0.6286 - val_loss: 3.2221
# Epoch 11/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8920 - loss: 0.2420 - val_accuracy: 0.6286 - val_loss: 2.7327
# Epoch 12/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8968 - loss: 0.3163 - val_accuracy: 0.5429 - val_loss: 2.5133
# Epoch 13/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.8723 - loss: 0.3410 - val_accuracy: 0.6286 - val_loss: 2.8541
# Epoch 14/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9417 - loss: 0.2037 - val_accuracy: 0.7143 - val_loss: 2.1525
# Epoch 15/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.8992 - loss: 0.2238 - val_accuracy: 0.5714 - val_loss: 1.5673
# Epoch 16/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9374 - loss: 0.1870 - val_accuracy: 0.6286 - val_loss: 2.7534
# Epoch 17/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.9183 - loss: 0.1798 - val_accuracy: 0.6000 - val_loss: 3.1379
# Epoch 18/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9214 - loss: 0.1590 - val_accuracy: 0.6286 - val_loss: 3.7630
# Epoch 19/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9122 - loss: 0.1899 - val_accuracy: 0.6857 - val_loss: 1.8398
# Epoch 20/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - accuracy: 0.9418 - loss: 0.2245 - val_accuracy: 0.6857 - val_loss: 3.1636
# Epoch 21/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9355 - loss: 0.1653 - val_accuracy: 0.6000 - val_loss: 3.4196
# Epoch 22/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8819 - loss: 0.3111 - val_accuracy: 0.5429 - val_loss: 3.4732
# Epoch 23/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8692 - loss: 0.3464 - val_accuracy: 0.6286 - val_loss: 3.0187
# Epoch 24/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 6s/step - accuracy: 0.8799 - loss: 0.3060 - val_accuracy: 0.7429 - val_loss: 1.9341
# Epoch 25/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8173 - loss: 0.4238 - val_accuracy: 0.6571 - val_loss: 2.4398
# Epoch 26/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 8s/step - accuracy: 0.8571 - loss: 0.4071 - val_accuracy: 0.6571 - val_loss: 2.1384
# Epoch 27/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8646 - loss: 0.3414 - val_accuracy: 0.6571 - val_loss: 1.3736
# Epoch 28/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8340 - loss: 0.3940 - val_accuracy: 0.6000 - val_loss: 2.7032
# Epoch 29/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.9442 - loss: 0.2301 - val_accuracy: 0.7429 - val_loss: 2.7515
# Epoch 30/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9069 - loss: 0.2215 - val_accuracy: 0.5429 - val_loss: 2.6304
# Epoch 31/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.8328 - loss: 0.3804 - val_accuracy: 0.6571 - val_loss: 2.9375
# Epoch 32/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9061 - loss: 0.2166 - val_accuracy: 0.6571 - val_loss: 3.0632
# Epoch 33/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8361 - loss: 0.3594 - val_accuracy: 0.6857 - val_loss: 4.1671
# Epoch 34/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8927 - loss: 0.2553 - val_accuracy: 0.7429 - val_loss: 2.8960
# Epoch 35/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.8677 - loss: 0.2669 - val_accuracy: 0.6286 - val_loss: 2.8334
# Epoch 36/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9150 - loss: 0.2188 - val_accuracy: 0.7143 - val_loss: 2.5742
# Epoch 37/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.9069 - loss: 0.2106 - val_accuracy: 0.7143 - val_loss: 2.4777
# Epoch 38/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 47s 9s/step - accuracy: 0.8958 - loss: 0.2126 - val_accuracy: 0.5143 - val_loss: 1.7978
# Epoch 39/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.9246 - loss: 0.1877 - val_accuracy: 0.6000 - val_loss: 2.7013
# Epoch 40/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8999 - loss: 0.3178 - val_accuracy: 0.6571 - val_loss: 3.1149
# Epoch 41/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9152 - loss: 0.2525 - val_accuracy: 0.4571 - val_loss: 2.7985
# Epoch 42/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9165 - loss: 0.2470 - val_accuracy: 0.6286 - val_loss: 3.3385
# Epoch 43/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9072 - loss: 0.2827 - val_accuracy: 0.6571 - val_loss: 2.0614
# Epoch 44/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9115 - loss: 0.2169 - val_accuracy: 0.6571 - val_loss: 2.4980
# Epoch 45/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9180 - loss: 0.3213 - val_accuracy: 0.6000 - val_loss: 2.6175
# Epoch 46/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9341 - loss: 0.1933 - val_accuracy: 0.6571 - val_loss: 3.8354
# Epoch 47/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9145 - loss: 0.2496 - val_accuracy: 0.6857 - val_loss: 3.8407
# Epoch 48/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9146 - loss: 0.2502 - val_accuracy: 0.6000 - val_loss: 3.1444
# Epoch 49/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8674 - loss: 0.3247 - val_accuracy: 0.4857 - val_loss: 2.7540
# Epoch 50/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8736 - loss: 0.2363 - val_accuracy: 0.6000 - val_loss: 2.6084
# Epoch 51/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8645 - loss: 0.3235 - val_accuracy: 0.5714 - val_loss: 3.1341
# Epoch 52/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8586 - loss: 0.3189 - val_accuracy: 0.6571 - val_loss: 2.2016
# Epoch 53/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9476 - loss: 0.1469 - val_accuracy: 0.6857 - val_loss: 2.2727
# Epoch 54/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9073 - loss: 0.1891 - val_accuracy: 0.6571 - val_loss: 2.7234
# Epoch 55/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9575 - loss: 0.1781 - val_accuracy: 0.6000 - val_loss: 2.2070
# Epoch 56/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9023 - loss: 0.2259 - val_accuracy: 0.6000 - val_loss: 3.1413
# Epoch 57/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9013 - loss: 0.2221 - val_accuracy: 0.6286 - val_loss: 3.5290
# Epoch 58/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9675 - loss: 0.1253 - val_accuracy: 0.6571 - val_loss: 3.8205
# Epoch 59/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9433 - loss: 0.1663 - val_accuracy: 0.5714 - val_loss: 3.0137
# Epoch 60/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9243 - loss: 0.1731 - val_accuracy: 0.6286 - val_loss: 4.3056
# Epoch 61/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 46s 8s/step - accuracy: 0.9314 - loss: 0.1707 - val_accuracy: 0.6857 - val_loss: 3.2009
# Epoch 62/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 7s/step - accuracy: 0.9357 - loss: 0.2326 - val_accuracy: 0.6000 - val_loss: 3.1348
# Epoch 63/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.8987 - loss: 0.3457 - val_accuracy: 0.6857 - val_loss: 3.2555
# Epoch 64/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9326 - loss: 0.1703 - val_accuracy: 0.5714 - val_loss: 3.4694
# Epoch 65/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.8947 - loss: 0.2700 - val_accuracy: 0.6286 - val_loss: 2.2471
# Epoch 66/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9015 - loss: 0.1829 - val_accuracy: 0.6286 - val_loss: 3.1491
# Epoch 67/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9383 - loss: 0.1688 - val_accuracy: 0.6571 - val_loss: 3.5099
# Epoch 68/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.9313 - loss: 0.1379 - val_accuracy: 0.6571 - val_loss: 2.9599
# Epoch 69/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9126 - loss: 0.1483 - val_accuracy: 0.6857 - val_loss: 2.4913
# Epoch 70/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9234 - loss: 0.1674 - val_accuracy: 0.6857 - val_loss: 3.1417
# Epoch 71/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.9445 - loss: 0.1463 - val_accuracy: 0.6286 - val_loss: 3.0091
# Epoch 72/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8781 - loss: 0.3289 - val_accuracy: 0.6000 - val_loss: 3.7422
# Epoch 73/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8540 - loss: 0.2732 - val_accuracy: 0.7143 - val_loss: 4.1728
# Epoch 74/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9016 - loss: 0.1994 - val_accuracy: 0.5714 - val_loss: 3.7575
# Epoch 75/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9069 - loss: 0.2456 - val_accuracy: 0.6000 - val_loss: 3.4928
# Epoch 76/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.9059 - loss: 0.2435 - val_accuracy: 0.6571 - val_loss: 4.1360
# Epoch 77/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9019 - loss: 0.2136 - val_accuracy: 0.6571 - val_loss: 4.2550
# Epoch 78/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8676 - loss: 0.3487 - val_accuracy: 0.5429 - val_loss: 3.2143
# Epoch 79/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9301 - loss: 0.1577 - val_accuracy: 0.5714 - val_loss: 2.8656
# Epoch 80/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9291 - loss: 0.2118 - val_accuracy: 0.6571 - val_loss: 3.1288
# Epoch 81/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9389 - loss: 0.2279 - val_accuracy: 0.6000 - val_loss: 4.1590
# Epoch 82/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 7s/step - accuracy: 0.9312 - loss: 0.1597 - val_accuracy: 0.6286 - val_loss: 3.7368
# Epoch 83/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.9068 - loss: 0.1850 - val_accuracy: 0.6000 - val_loss: 2.6297
# Epoch 84/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9554 - loss: 0.1786 - val_accuracy: 0.5714 - val_loss: 3.3282
# Epoch 85/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9408 - loss: 0.1984 - val_accuracy: 0.7143 - val_loss: 2.9596
# Epoch 86/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9559 - loss: 0.1389 - val_accuracy: 0.5714 - val_loss: 2.7040
# Epoch 87/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8626 - loss: 0.3866 - val_accuracy: 0.6000 - val_loss: 3.3728
# Epoch 88/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9020 - loss: 0.2198 - val_accuracy: 0.6857 - val_loss: 2.1848
# Epoch 89/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19477s 4866s/step - accuracy: 0.8842 - loss: 0.3221 - val_accuracy: 0.5714 - val_loss: 2.6995
# Epoch 90/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 94s 7s/step - accuracy: 0.9144 - loss: 0.2301 - val_accuracy: 0.5429 - val_loss: 2.7368
# Epoch 91/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9277 - loss: 0.1970 - val_accuracy: 0.6000 - val_loss: 2.3600
# Epoch 92/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9091 - loss: 0.2334 - val_accuracy: 0.6000 - val_loss: 2.6145
# Epoch 93/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9059 - loss: 0.2222 - val_accuracy: 0.6286 - val_loss: 2.2401
# Epoch 94/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9391 - loss: 0.1496 - val_accuracy: 0.6000 - val_loss: 3.3237
# Epoch 95/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9016 - loss: 0.2245 - val_accuracy: 0.7429 - val_loss: 2.9960
# Epoch 96/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 30s 5s/step - accuracy: 0.8699 - loss: 0.2451 - val_accuracy: 0.6000 - val_loss: 3.4515
# Epoch 97/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - accuracy: 0.9088 - loss: 0.2870 - val_accuracy: 0.6857 - val_loss: 2.4179
# Epoch 98/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.9039 - loss: 0.2985 - val_accuracy: 0.5714 - val_loss: 4.2417
# Epoch 99/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 6s/step - accuracy: 0.9157 - loss: 0.2075 - val_accuracy: 0.6857 - val_loss: 4.0255
# Epoch 100/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.8795 - loss: 0.2361 - val_accuracy: 0.7143 - val_loss: 3.3902
# Epoch 101/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.9503 - loss: 0.1532 - val_accuracy: 0.5429 - val_loss: 2.3822
# Epoch 102/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.9119 - loss: 0.2445 - val_accuracy: 0.5429 - val_loss: 3.0003
# Epoch 103/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.9314 - loss: 0.1547 - val_accuracy: 0.6571 - val_loss: 4.1169
# Epoch 104/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 6s/step - accuracy: 0.9442 - loss: 0.1694 - val_accuracy: 0.7143 - val_loss: 1.9022
# Epoch 105/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9709 - loss: 0.1059 - val_accuracy: 0.5714 - val_loss: 3.0488
# Epoch 106/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9488 - loss: 0.1368 - val_accuracy: 0.6000 - val_loss: 3.0021
# Epoch 107/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9228 - loss: 0.1655 - val_accuracy: 0.7143 - val_loss: 2.6068
# Epoch 108/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9447 - loss: 0.2022 - val_accuracy: 0.7429 - val_loss: 2.9961
# Epoch 109/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9323 - loss: 0.1531 - val_accuracy: 0.6857 - val_loss: 2.9368
# Epoch 110/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 8s/step - accuracy: 0.9479 - loss: 0.1803 - val_accuracy: 0.7143 - val_loss: 2.8298
# Epoch 111/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9292 - loss: 0.2483 - val_accuracy: 0.6000 - val_loss: 3.3118
# Epoch 112/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9094 - loss: 0.2230 - val_accuracy: 0.6857 - val_loss: 3.0294
# Epoch 113/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9178 - loss: 0.1879 - val_accuracy: 0.6857 - val_loss: 2.3100
# Epoch 114/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9478 - loss: 0.1431 - val_accuracy: 0.6571 - val_loss: 3.0602
# Epoch 115/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.9568 - loss: 0.1021 - val_accuracy: 0.6286 - val_loss: 4.3821
# Epoch 116/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9226 - loss: 0.1353 - val_accuracy: 0.6571 - val_loss: 3.3952
# Epoch 117/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9346 - loss: 0.1307 - val_accuracy: 0.6000 - val_loss: 4.2405
# Epoch 118/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9211 - loss: 0.1857 - val_accuracy: 0.5714 - val_loss: 3.7780
# Epoch 119/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9206 - loss: 0.1649 - val_accuracy: 0.6571 - val_loss: 3.3026
# Epoch 120/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9138 - loss: 0.1873 - val_accuracy: 0.6857 - val_loss: 3.0840
# Epoch 121/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9477 - loss: 0.1402 - val_accuracy: 0.6286 - val_loss: 2.9030
# Epoch 122/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9163 - loss: 0.2083 - val_accuracy: 0.4857 - val_loss: 3.1639
# Epoch 123/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9192 - loss: 0.2252 - val_accuracy: 0.6286 - val_loss: 3.8124
# Epoch 124/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8743 - loss: 0.2694 - val_accuracy: 0.5429 - val_loss: 3.2196
# Epoch 125/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9202 - loss: 0.1588 - val_accuracy: 0.6000 - val_loss: 2.6058
# Epoch 126/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9164 - loss: 0.1907 - val_accuracy: 0.6286 - val_loss: 3.6258
# Epoch 127/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.8894 - loss: 0.2544 - val_accuracy: 0.7143 - val_loss: 3.2242
# Epoch 128/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 7s/step - accuracy: 0.9392 - loss: 0.1361 - val_accuracy: 0.6857 - val_loss: 3.3677
# Epoch 129/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 7s/step - accuracy: 0.9662 - loss: 0.1425 - val_accuracy: 0.5143 - val_loss: 3.4837
# Epoch 130/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 7s/step - accuracy: 0.9243 - loss: 0.1747 - val_accuracy: 0.6571 - val_loss: 3.0955
# Epoch 131/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 8s/step - accuracy: 0.9376 - loss: 0.1796 - val_accuracy: 0.5714 - val_loss: 4.6077
# Epoch 132/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9120 - loss: 0.2792 - val_accuracy: 0.5714 - val_loss: 2.8279
# Epoch 133/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.8840 - loss: 0.2288 - val_accuracy: 0.6571 - val_loss: 2.9427
# Epoch 134/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.9407 - loss: 0.1845 - val_accuracy: 0.7143 - val_loss: 3.0277
# Epoch 135/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 8s/step - accuracy: 0.8771 - loss: 0.2173 - val_accuracy: 0.6000 - val_loss: 3.3077
# Epoch 136/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 8s/step - accuracy: 0.8877 - loss: 0.2450 - val_accuracy: 0.6000 - val_loss: 2.8233
# Epoch 137/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9133 - loss: 0.1871 - val_accuracy: 0.7143 - val_loss: 2.4935
# Epoch 138/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.8875 - loss: 0.2258 - val_accuracy: 0.6571 - val_loss: 3.0187
# Epoch 139/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9540 - loss: 0.1683 - val_accuracy: 0.6286 - val_loss: 4.2290
# Epoch 140/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9484 - loss: 0.1297 - val_accuracy: 0.6571 - val_loss: 3.4277
# Epoch 141/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.8545 - loss: 0.2227 - val_accuracy: 0.5714 - val_loss: 2.6945
# Epoch 142/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.8964 - loss: 0.2062 - val_accuracy: 0.5429 - val_loss: 4.0022
# Epoch 143/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8890 - loss: 0.2988 - val_accuracy: 0.6571 - val_loss: 3.6083
# Epoch 144/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.8973 - loss: 0.2486 - val_accuracy: 0.5429 - val_loss: 3.1263
# Epoch 145/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9393 - loss: 0.1960 - val_accuracy: 0.5429 - val_loss: 2.4103
# Epoch 146/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9254 - loss: 0.1987 - val_accuracy: 0.5714 - val_loss: 3.0020
# Epoch 147/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9436 - loss: 0.1950 - val_accuracy: 0.6571 - val_loss: 2.6092
# Epoch 148/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.9367 - loss: 0.2354 - val_accuracy: 0.5429 - val_loss: 2.5339
# Epoch 149/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9152 - loss: 0.2360 - val_accuracy: 0.6000 - val_loss: 3.5620
# Epoch 150/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 46s 8s/step - accuracy: 0.9771 - loss: 0.1229 - val_accuracy: 0.5714 - val_loss: 2.6046
# Epoch 151/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9488 - loss: 0.1394 - val_accuracy: 0.6571 - val_loss: 3.0881
# Epoch 152/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9674 - loss: 0.1065 - val_accuracy: 0.5714 - val_loss: 4.1126
# Epoch 153/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9256 - loss: 0.1529 - val_accuracy: 0.6000 - val_loss: 4.0957
# Epoch 154/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9528 - loss: 0.1533 - val_accuracy: 0.4857 - val_loss: 3.8034
# Epoch 155/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9448 - loss: 0.1454 - val_accuracy: 0.6857 - val_loss: 2.8441
# Epoch 156/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9531 - loss: 0.1466 - val_accuracy: 0.6286 - val_loss: 3.8218
# Epoch 157/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9618 - loss: 0.1111 - val_accuracy: 0.5429 - val_loss: 4.2332
# Epoch 158/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 8s/step - accuracy: 0.8677 - loss: 0.3549 - val_accuracy: 0.6000 - val_loss: 3.6010
# Epoch 159/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.9078 - loss: 0.3463 - val_accuracy: 0.5143 - val_loss: 2.5338
# Epoch 160/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.8938 - loss: 0.2916 - val_accuracy: 0.5429 - val_loss: 3.3666
# Epoch 161/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9185 - loss: 0.3208 - val_accuracy: 0.5429 - val_loss: 2.3528
# Epoch 162/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9358 - loss: 0.2102 - val_accuracy: 0.6286 - val_loss: 3.3552
# Epoch 163/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8638 - loss: 0.4277 - val_accuracy: 0.5714 - val_loss: 3.3655
# Epoch 164/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9126 - loss: 0.2047 - val_accuracy: 0.6571 - val_loss: 2.6587
# Epoch 165/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9234 - loss: 0.1619 - val_accuracy: 0.6000 - val_loss: 2.1770
# Epoch 166/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8916 - loss: 0.2577 - val_accuracy: 0.6000 - val_loss: 2.4351
# Epoch 167/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9165 - loss: 0.1747 - val_accuracy: 0.6286 - val_loss: 2.4797
# Epoch 168/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9359 - loss: 0.1767 - val_accuracy: 0.6000 - val_loss: 3.1517
# Epoch 169/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9375 - loss: 0.2503 - val_accuracy: 0.6571 - val_loss: 2.6903
# Epoch 170/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9352 - loss: 0.1806 - val_accuracy: 0.5429 - val_loss: 3.5351
# Epoch 171/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9262 - loss: 0.1831 - val_accuracy: 0.6286 - val_loss: 3.5419
# Epoch 172/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9181 - loss: 0.1591 - val_accuracy: 0.6286 - val_loss: 2.8431
# Epoch 173/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.9310 - loss: 0.1495 - val_accuracy: 0.6571 - val_loss: 2.9334
# Epoch 174/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.8791 - loss: 0.2226 - val_accuracy: 0.6286 - val_loss: 3.6375
# Epoch 175/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9066 - loss: 0.2056 - val_accuracy: 0.5714 - val_loss: 2.8302
# Epoch 176/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8943 - loss: 0.2303 - val_accuracy: 0.6857 - val_loss: 2.4297
# Epoch 177/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8654 - loss: 0.2515 - val_accuracy: 0.6857 - val_loss: 2.4347
# Epoch 178/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9015 - loss: 0.2238 - val_accuracy: 0.6857 - val_loss: 2.8653
# Epoch 179/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8712 - loss: 0.2474 - val_accuracy: 0.6286 - val_loss: 3.1314
# Epoch 180/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9561 - loss: 0.1788 - val_accuracy: 0.6286 - val_loss: 3.3722
# Epoch 181/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9384 - loss: 0.1524 - val_accuracy: 0.6286 - val_loss: 2.7334
# Epoch 182/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9399 - loss: 0.1467 - val_accuracy: 0.6571 - val_loss: 2.8680
# Epoch 183/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9484 - loss: 0.1342 - val_accuracy: 0.6571 - val_loss: 3.6945
# Epoch 184/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9315 - loss: 0.1580 - val_accuracy: 0.6571 - val_loss: 3.1870
# Epoch 185/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9545 - loss: 0.1192 - val_accuracy: 0.6857 - val_loss: 4.0355
# Epoch 186/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9760 - loss: 0.0904 - val_accuracy: 0.7143 - val_loss: 3.3838
# Epoch 187/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9674 - loss: 0.0842 - val_accuracy: 0.5429 - val_loss: 4.5175
# Epoch 188/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9594 - loss: 0.0836 - val_accuracy: 0.6571 - val_loss: 3.8384
# Epoch 189/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9566 - loss: 0.1254 - val_accuracy: 0.6857 - val_loss: 3.4783
# Epoch 190/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9566 - loss: 0.1184 - val_accuracy: 0.6000 - val_loss: 3.5406
# Epoch 191/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9840 - loss: 0.0882 - val_accuracy: 0.5429 - val_loss: 3.8046
# Epoch 192/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9111 - loss: 0.1745 - val_accuracy: 0.6286 - val_loss: 5.0108
# Epoch 193/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9450 - loss: 0.1849 - val_accuracy: 0.6286 - val_loss: 6.1766
# Epoch 194/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8981 - loss: 0.3296 - val_accuracy: 0.6286 - val_loss: 3.5521
# Epoch 195/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9362 - loss: 0.2751 - val_accuracy: 0.7429 - val_loss: 2.3616
# Epoch 196/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8981 - loss: 0.2054 - val_accuracy: 0.6571 - val_loss: 2.2900
# Epoch 197/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8955 - loss: 0.2586 - val_accuracy: 0.5714 - val_loss: 2.5743
# Epoch 198/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9204 - loss: 0.2297 - val_accuracy: 0.5143 - val_loss: 2.7711
# Epoch 199/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9112 - loss: 0.2019 - val_accuracy: 0.5143 - val_loss: 3.4380
# Epoch 200/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9155 - loss: 0.1793 - val_accuracy: 0.7143 - val_loss: 3.4102
# Epoch 201/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9042 - loss: 0.2346 - val_accuracy: 0.7429 - val_loss: 3.9262
# Epoch 202/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9297 - loss: 0.1572 - val_accuracy: 0.5143 - val_loss: 3.5264
# Epoch 203/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9289 - loss: 0.1874 - val_accuracy: 0.6000 - val_loss: 3.3022
# Epoch 204/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9260 - loss: 0.1909 - val_accuracy: 0.6286 - val_loss: 3.1398
# Epoch 205/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9383 - loss: 0.2127 - val_accuracy: 0.6286 - val_loss: 3.7797
# Epoch 206/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9376 - loss: 0.1507 - val_accuracy: 0.6857 - val_loss: 3.8390
# Epoch 207/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9085 - loss: 0.2460 - val_accuracy: 0.6000 - val_loss: 5.4755
# Epoch 208/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8886 - loss: 0.2338 - val_accuracy: 0.5429 - val_loss: 5.3710
# Epoch 209/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8829 - loss: 0.2876 - val_accuracy: 0.6571 - val_loss: 3.1783
# Epoch 210/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8909 - loss: 0.2786 - val_accuracy: 0.5714 - val_loss: 4.2338
# Epoch 211/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9501 - loss: 0.1625 - val_accuracy: 0.5714 - val_loss: 4.1207
# Epoch 212/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8566 - loss: 0.2977 - val_accuracy: 0.6286 - val_loss: 3.5736
# Epoch 213/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9481 - loss: 0.1384 - val_accuracy: 0.6857 - val_loss: 3.6379
# Epoch 214/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9133 - loss: 0.2434 - val_accuracy: 0.6857 - val_loss: 3.4979
# Epoch 215/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9636 - loss: 0.1298 - val_accuracy: 0.5429 - val_loss: 3.6323
# Epoch 216/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9510 - loss: 0.1866 - val_accuracy: 0.5714 - val_loss: 3.4361
# Epoch 217/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9082 - loss: 0.1972 - val_accuracy: 0.6571 - val_loss: 3.0767
# Epoch 218/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9371 - loss: 0.1938 - val_accuracy: 0.6857 - val_loss: 3.1942
# Epoch 219/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9104 - loss: 0.2113 - val_accuracy: 0.6000 - val_loss: 3.4255
# Epoch 220/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9584 - loss: 0.1283 - val_accuracy: 0.5714 - val_loss: 3.4742
# Epoch 221/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9159 - loss: 0.1468 - val_accuracy: 0.6857 - val_loss: 2.8410
# Epoch 222/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8868 - loss: 0.2321 - val_accuracy: 0.5143 - val_loss: 2.8475
# Epoch 223/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9095 - loss: 0.2493 - val_accuracy: 0.6571 - val_loss: 3.4597
# Epoch 224/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9029 - loss: 0.1673 - val_accuracy: 0.6000 - val_loss: 3.5476
# Epoch 225/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9024 - loss: 0.1808 - val_accuracy: 0.6000 - val_loss: 3.4686
# Epoch 226/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9584 - loss: 0.1530 - val_accuracy: 0.6000 - val_loss: 3.1186
# Epoch 227/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9357 - loss: 0.1486 - val_accuracy: 0.7143 - val_loss: 3.1289
# Epoch 228/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9436 - loss: 0.1420 - val_accuracy: 0.6286 - val_loss: 3.5945
# Epoch 229/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9097 - loss: 0.2554 - val_accuracy: 0.6857 - val_loss: 3.6773
# Epoch 230/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9369 - loss: 0.1811 - val_accuracy: 0.6000 - val_loss: 4.4449
# Epoch 231/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9074 - loss: 0.2192 - val_accuracy: 0.5714 - val_loss: 3.2568
# Epoch 232/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9769 - loss: 0.1340 - val_accuracy: 0.7429 - val_loss: 2.4408
# Epoch 233/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9479 - loss: 0.1343 - val_accuracy: 0.6286 - val_loss: 3.2721
# Epoch 234/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9107 - loss: 0.2238 - val_accuracy: 0.6286 - val_loss: 3.7533
# Epoch 235/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9507 - loss: 0.1961 - val_accuracy: 0.6857 - val_loss: 2.5884
# Epoch 236/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9582 - loss: 0.1788 - val_accuracy: 0.5714 - val_loss: 3.0458
# Epoch 237/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9427 - loss: 0.1246 - val_accuracy: 0.7429 - val_loss: 3.7161
# Epoch 238/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8896 - loss: 0.2409 - val_accuracy: 0.6857 - val_loss: 3.0072
# Epoch 239/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8721 - loss: 0.3166 - val_accuracy: 0.6286 - val_loss: 2.3748
# Epoch 240/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9274 - loss: 0.1747 - val_accuracy: 0.6286 - val_loss: 3.3562
# Epoch 241/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9332 - loss: 0.1371 - val_accuracy: 0.5714 - val_loss: 3.4619
# Epoch 242/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9345 - loss: 0.1207 - val_accuracy: 0.6000 - val_loss: 3.6561
# Epoch 243/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9409 - loss: 0.1267 - val_accuracy: 0.6286 - val_loss: 3.7343
# Epoch 244/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9544 - loss: 0.1051 - val_accuracy: 0.6857 - val_loss: 3.6340
# Epoch 245/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9628 - loss: 0.0945 - val_accuracy: 0.6000 - val_loss: 4.8499
# Epoch 246/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9588 - loss: 0.1146 - val_accuracy: 0.6571 - val_loss: 3.6152
# Epoch 247/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9360 - loss: 0.1579 - val_accuracy: 0.6286 - val_loss: 3.6632
# Epoch 248/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9277 - loss: 0.1775 - val_accuracy: 0.5714 - val_loss: 5.1055
# Epoch 249/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9373 - loss: 0.1477 - val_accuracy: 0.6000 - val_loss: 3.5994
# Epoch 250/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9602 - loss: 0.0965 - val_accuracy: 0.5429 - val_loss: 4.6019
# Epoch 251/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9358 - loss: 0.1289 - val_accuracy: 0.6286 - val_loss: 3.7764
# Epoch 252/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9514 - loss: 0.1174 - val_accuracy: 0.7143 - val_loss: 3.3537
# Epoch 253/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9531 - loss: 0.0998 - val_accuracy: 0.6286 - val_loss: 2.6755
# Epoch 254/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9209 - loss: 0.1779 - val_accuracy: 0.6857 - val_loss: 2.3263
# Epoch 255/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9944 - loss: 0.0610 - val_accuracy: 0.6857 - val_loss: 4.2943
# Epoch 256/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9106 - loss: 0.1677 - val_accuracy: 0.6286 - val_loss: 5.1605
# Epoch 257/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9427 - loss: 0.1426 - val_accuracy: 0.5714 - val_loss: 4.7591
# Epoch 258/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9661 - loss: 0.0925 - val_accuracy: 0.6571 - val_loss: 3.5762
# Epoch 259/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9493 - loss: 0.1307 - val_accuracy: 0.6571 - val_loss: 5.6204
# Epoch 260/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9860 - loss: 0.0751 - val_accuracy: 0.5714 - val_loss: 4.7248
# Epoch 261/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9446 - loss: 0.1220 - val_accuracy: 0.5429 - val_loss: 5.1079
# Epoch 262/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9340 - loss: 0.1410 - val_accuracy: 0.6857 - val_loss: 3.6583
# Epoch 263/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8991 - loss: 0.2868 - val_accuracy: 0.6000 - val_loss: 3.5166
# Epoch 264/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9467 - loss: 0.1609 - val_accuracy: 0.6286 - val_loss: 4.1649
# Epoch 265/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9572 - loss: 0.0936 - val_accuracy: 0.5143 - val_loss: 5.6652
# Epoch 266/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9180 - loss: 0.2176 - val_accuracy: 0.5714 - val_loss: 4.6096
# Epoch 267/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9623 - loss: 0.1165 - val_accuracy: 0.7143 - val_loss: 4.6443
# Epoch 268/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9241 - loss: 0.1845 - val_accuracy: 0.6286 - val_loss: 4.6227
# Epoch 269/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8882 - loss: 0.2513 - val_accuracy: 0.5429 - val_loss: 4.0482
# Epoch 270/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9152 - loss: 0.2566 - val_accuracy: 0.5429 - val_loss: 3.6985
# Epoch 271/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9297 - loss: 0.1670 - val_accuracy: 0.6857 - val_loss: 4.9752
# Epoch 272/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8548 - loss: 0.2300 - val_accuracy: 0.6571 - val_loss: 4.3878
# Epoch 273/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9294 - loss: 0.1650 - val_accuracy: 0.5429 - val_loss: 4.4618
# Epoch 274/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9081 - loss: 0.2258 - val_accuracy: 0.6286 - val_loss: 4.2206
# Epoch 275/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9493 - loss: 0.1554 - val_accuracy: 0.5714 - val_loss: 4.0209
# Epoch 276/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8729 - loss: 0.2603 - val_accuracy: 0.6571 - val_loss: 3.8357
# Epoch 277/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.8958 - loss: 0.4128 - val_accuracy: 0.5429 - val_loss: 3.5844
# Epoch 278/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9177 - loss: 0.2349 - val_accuracy: 0.6000 - val_loss: 2.3038
# Epoch 279/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9265 - loss: 0.1570 - val_accuracy: 0.6000 - val_loss: 3.2989
# Epoch 280/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.8651 - loss: 0.2697 - val_accuracy: 0.6000 - val_loss: 2.7156
# Epoch 281/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.8942 - loss: 0.1765 - val_accuracy: 0.5714 - val_loss: 3.6129
# Epoch 282/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 8s/step - accuracy: 0.9281 - loss: 0.1545 - val_accuracy: 0.7143 - val_loss: 3.0304
# Epoch 283/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 7s/step - accuracy: 0.8661 - loss: 0.2370 - val_accuracy: 0.6857 - val_loss: 3.6953
# Epoch 284/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.9516 - loss: 0.1226 - val_accuracy: 0.6571 - val_loss: 4.8730
# Epoch 285/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9287 - loss: 0.1971 - val_accuracy: 0.6286 - val_loss: 2.9353
# Epoch 286/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9629 - loss: 0.1167 - val_accuracy: 0.6286 - val_loss: 3.1661
# Epoch 287/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9328 - loss: 0.1810 - val_accuracy: 0.6286 - val_loss: 4.1432
# Epoch 288/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9619 - loss: 0.1166 - val_accuracy: 0.6857 - val_loss: 4.8469
# Epoch 289/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9590 - loss: 0.0927 - val_accuracy: 0.6000 - val_loss: 4.7106
# Epoch 290/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9283 - loss: 0.2297 - val_accuracy: 0.6000 - val_loss: 5.0850
# Epoch 291/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9562 - loss: 0.1354 - val_accuracy: 0.6000 - val_loss: 4.5388
# Epoch 292/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.8820 - loss: 0.2592 - val_accuracy: 0.7143 - val_loss: 3.4347
# Epoch 293/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - accuracy: 0.9816 - loss: 0.0831 - val_accuracy: 0.6286 - val_loss: 3.1779
# Epoch 294/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9484 - loss: 0.1150 - val_accuracy: 0.5714 - val_loss: 4.0614
# Epoch 295/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9345 - loss: 0.1281 - val_accuracy: 0.6571 - val_loss: 3.7976
# Epoch 296/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9235 - loss: 0.2067 - val_accuracy: 0.6000 - val_loss: 3.3485
# Epoch 297/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9472 - loss: 0.1230 - val_accuracy: 0.7143 - val_loss: 3.5525
# Epoch 298/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9057 - loss: 0.2253 - val_accuracy: 0.5714 - val_loss: 2.5811
# Epoch 299/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.9380 - loss: 0.2366 - val_accuracy: 0.6000 - val_loss: 4.1506
# Epoch 300/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.9047 - loss: 0.2093 - val_accuracy: 0.6000 - val_loss: 3.4864

# %% [markdown]
# **Evaluating the Trained Model on the Validation Dataset**

# %% [markdown]
# This code evaluates the trained model on the validation dataset and prints the validation accuracy as a percentage.

# %%
# Evaluate model
loss, accuracy = model.evaluate(validation_generator)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.6568 - loss: 2.9717
# Validation Accuracy: 65.71%
